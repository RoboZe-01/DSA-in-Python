# %% [markdown]
# # Print Function

# %%
age = 22
name = 'prem'

print('hello world ')
print('I am ', name)
# Out:
# hello world
# I am  prem

# %% [markdown]
# This makes print on saperate line

# %%
# if we want to print on same line 

print("Hello world" , end=" | ")    # Same line but with 
print("I am ", name)
# Out:
# Hello world | I am  prem

# %% [markdown]
# ## F string

# %%
# used for when we want to use variables in print function 

print(f'Hi {name} , how are you ! ')
# Out:
# Hi prem , how are you !
