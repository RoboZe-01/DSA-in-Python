# %% [markdown]
# # Online Shopping Cart (Composition + Real World)
#
# Requirements:
#
# Class Product with: name, price, stock
#
# Method is_available()
#
# Class CartItem with: product, quantity
#
# Method get_subtotal()
#
# Class ShoppingCart (contains CartItems)
#
# Methods: add_product(), remove_product(), calculate_total(), display_cart()
#
# Class Customer with: name, email, cart (composition)
#
# Method checkout() that checks stock and clears cart
#
# Test adding products and checking out

# %%
class Product : 

    # data property 
    def __init__(self,name,price,stock):
        self.name = name
        self.price = price 
        self.stock = stock

    def is_available(self) :
