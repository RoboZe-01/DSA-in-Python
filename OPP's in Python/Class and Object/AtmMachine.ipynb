# %% [markdown]
# # Class and object will we learn it hands on

# %% [markdown]
# ## **Atm Application - Project**

# %%
# Initialize the class

class AtmMachine:

    # data property
    def __init__(self):
        self.pin = ""
        self.balance = 0
    

    # behaviour property
    def menu(self):
        user_input = input(
            """
          Hello ,how can we help you ?
          1. Press 1 to check the balance
          2. Press 2 to withdraw
          3. Press 3 to deposit
          4. Press 4 to create pin
          5. Press 4 to change the pin

          Press anything to exit (can press enter)
            """
        )

        if user_input =="1":
            # Check balance code
            pass

        elif user_input=="2":
            # money withdraw code
            pass
        elif user_input=="3":
            # Deposit code
            pass
        elif user_input=="4":
            self.create_pin()
            pass
        elif user_input=="5":
            # change pin code
            pass
        else:
            exit()



     ## Creating functionality for the project

     # Create pin function       
    def create_pin(self):
        user_pin = int(input("Create your pin (numbers only) : "))
        self.pin = user_pin
        print("Pin created successfully ")
        self.menu()        
    

    # Update Pin function
    def update_pin(self):
        user_input = int(input("Enter your old pin : "))

        if user_input==self.pin:
            new_pin = int(input("Set new Pin : "))
            self.pin = new_pin
# Out:
#   Cell In[4], line 61
#     if user_input==self.pin:
#                             ^
# SyntaxError: incomplete input

# %%
# object creation
obj = AtmMachine()
obj
