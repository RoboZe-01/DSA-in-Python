# %% [markdown]
# # Classes in Python
# It is a blueprint for creating objects , attributes , methods

# %%
class Car:
    pass                      # Initallly Car class does not have any atributes

audi = Car()
tata = Car()
print(type(audi))

audi.doors = 4                # New atributes is created for audi object
print(audi.doors)
# Out:
# <class '__main__.Car'>
# 4

# %% [markdown]
# Howeveer the atribute creation by using this way is not suitable for large scale project .
# We have to create some common atributes the class should have , and if something special to the specific object we can create using this method

# %% [markdown]
# ### Instances , variable and methods

# %%
class Dog:
    # class defination

    # constructor

    def __init__(self,name,age):
        self.name = name                  #self.name = instance variable 
        self.age = age        


 # Create objects

dog1 = Dog("Buddy",3)      # object initialised with positional arguments name and age
print(dog1) 
print(dog1.name)                            
print(dog1.age)
# Out:
# ...
# Buddy
# 3

# %% [markdown]
# class Dog:
#
#     # constructor
#
#     def __init__(self,name,age):
#         self.name = name                  #self.name = instance variable
#         self.age = age
#
#
#
# above is how we create a class
# this is the class of Dog with using a constructor and have (name,age) as the positional variable
#
# - name / age --> Positional arguments / parameters
# - self.name/self.age --> Instance varible of the class
#
# - __init__() : constructor and in that we have created some instance varible . these instance varible we can access but if we want to create new instance varible we have to create in (init) only we cannot create new instance varible outside the class

# %%
## Define a class with instance methods
class Dog:
    def __init__(self, name, age):
        self.name = name
        self.age = age

    def bark(self):
        print(f"{self.name} says woof")    


dog3=Dog("Rahul",4)
dog3.bark()
dog2=Dog("lucy",2)
dog2.bark()
# Out:
# Rahul says woof
# lucy says woof

# %%
### Modeling a Bank Account

## Define a Class for a bank account 

class BankAccount:
    def __init__(self,owner,balance=0):
        self.owner = owner
        self.balance = balance

    # deposit function

    def deposit(self,amount):
        self.balance+= amount
        print(f"{amount} is deposited . Balance is {self.balance}")
    
    # Withdraw function

    def withdraw(self,amount):
        if amount>self.balance:
            print("Insufficient funds!")  
        else:
            self.balance-=amount
            print(f"{amount} is withdrawn . New balance is {self.balance}")    


     # Check balance
    def get_balance(self):
        return self.balance 


## Create an account 
account1 = BankAccount("Prem",10000000)

# %%
account1.get_balance()
# Out:
# 10000001

# %%
account1.withdraw(1000)
# Out:
# 1000 is withdrawn . New balance is 9999001

# %%
account1.deposit(1)
# Out:
# 1 is deposited . Balance is 9999002

# %%
print(account1.get_balance())
# Out:
# 9999002
