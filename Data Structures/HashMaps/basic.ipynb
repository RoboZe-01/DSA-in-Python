# %% [markdown]
# # Hashmaps in Python
# - Prestoring of values
# - Same as dictionary in python/

# %% [markdown]
# ## Benefits of Hashmaps
#
# 1. Custom keys as earier for engineers to work with
# 2. Hashmaps allows for search O(1) , where arrays / linked list O(log(n))

# %% [markdown]
# ## Let us understand hashmaps with library analogy
#
# Imagine your'e at a massive library and you want to find the book of "Concepts of Physics" by "HC verma"
#
# There is two way you can do this, i.e good way and bad way
#
# - Bad way( array /List): Walking through every asile, checking every single book until you find it -> O(n) time
#
# - **Good way** ( Hashmap) = You have a magical catalog that tells you : "Books starting with 'T' are on Floor 3, aisle 5, Shelf 2" -> O(1) time
#
# That's exactly what a hashmap does!

# %% [markdown]
# ## What is a Hashmap ?
#
# A **hashmap** ( called dict in Python) stores **key-value pairs** . You give it a key, and it instantly gives you the value

# %%
# Creating a hashmap
grade = {

    "Prem" : 95,
    "Rahul": 87,
    "Subha" : 90,
    "Om" : 88
}

# Access - O(1) time!
print(grade['Om'])  # Output : 88
# Out:
# 88

# %% [markdown]
# ## Insert and Update

# %%
# Insert ( Key doesn't Exist)

grade["Yash"] = 55

# %%
grade
# Out:
# {'Prem': 95, 'Rahul': 87, 'Subha': 90, 'Om': 88, 'Yash': 55}

# %%
# Update (Key exist)
grade['Prem']= 99

# %%
# Insert multiple at once 
grade.update({"Sigrika" : 55,"Luuk":45})
grade
# Out:
# {'Prem': 99,
#  'Rahul': 87,
#  'Subha': 90,
#  'Om': 88,
#  'Yash': 55,
#  'Sigrika': 55,
#  'Luuk': 45}

# %% [markdown]
# ## Lookup Operations

# %% [markdown]
# ### Operation cheat sheet

# %% [markdown]
# ## 1. Create

# %%
a = {}                                      # Empty dict
b = {"a":1}                                 # With values
c = dict(a=1,b=2)                           # With kwargs
d = dict([("a",1),("b",2)])                 # with pair
e = {x:x**2 for x in range(5)}              # using comprehensions

# %%
print(a)
print(b)
print(c)
print(d)
print(e)
# Out:
# {}
# {'a': 1}
# {'a': 1, 'b': 2}
# {'a': 1, 'b': 2}
# {0: 0, 1: 1, 2: 4, 3: 9, 4: 16}

# %% [markdown]
# ## Read

# %%
d[a]     # Direct ( Gives keyerror if key missing)
d.get(a)    # Returns none if missing 
d.get(b)
