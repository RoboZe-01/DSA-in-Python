# %%
def greet():
    print("Welcome to the python !!")
    print("Welcome to the python !!")
    print("Welcome to the python !!")
    print("Welcome to the python !!")
    print("Welcome to the python !!")
    print("Welcome to the python !!")
    print("Welcome to the python !!")

greet()
# Out:
# Welcome to the python !!
# Welcome to the python !!
# Welcome to the python !!
# Welcome to the python !!
# Welcome to the python !!
# Welcome to the python !!
# Welcome to the python !!
