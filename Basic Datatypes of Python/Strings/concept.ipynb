# %% [markdown]
# # Strings in Python
# In python, strings can be created by enclosing the character or the sequence of characters in the quotes. Python allows us to use single quotes, double quotes, or triple quotes to create the string.

# %%
str1 = 'hello'
str2 ="Helo"
str3= """HELLO"""

# %% [markdown]
# In python, strings are treated as the sequence of characters which means that python doesn't support the character data type instead a single character written as 'p' is treated as the string of length 1.

# %% [markdown]
# # Python Indexing
#
# Like other languages, the indexing of the python strings starts from 0. For example, the string "HELLO" is indexed as given in the below figure.
#
# str="HELLO"

# %%
str = "HELLO"
print(str[0])
print(str[1])
print((str[2]))
# Out:
# H
# E
# L

# %% [markdown]
# - Python allows negative indexing for its sequences.
# - Index -1 refers to the last character , -2 second last and so on .

# %%
print(str[-1])
print(str[-2])
print(str[-3])
# Out:
# O
# L
# L

# %% [markdown]
# - String can be only replaced with another string .
# - String is immutable so it cannot be partially replaced

# %%
str[0]="a"
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 str[0]="a"
#
# TypeError: 'str' object does not support item assignment

# %%
str= "BYE"

# %%
print(str)
# Out:
# BYE

# %% [markdown]
# ## String Operations

# %% [markdown]
# ##  Python Example Program - Working with String Operators in Python

# %% [markdown]
# ## Python strings functions
